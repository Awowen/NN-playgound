# %% [markdown]
# # Keras test #3
# ## LSTM text generation - Generate Nitzshe writing
# ### Library imports

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load data

# %%
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# corpus length: 600893

# %% [markdown]
# ### Preprocess text

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# total chars: 57
# nb sequences: 200285

# %% [markdown]
# ### Vectorize text

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %% [markdown]
# ### Build a simple LSTM model

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %% [markdown]
# ### Custom functions

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# ### Run the model

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=30,
          callbacks=[print_callback])
# Out:
# Epoch 1/30
# 200192/200285 [============================>.] - ETA: 0s - loss: 2.0027
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ate is for the benefit,
# not of the jesui"
# ate is for the benefit,
# not of the jesuic of the first in the self and strens of the self-conception of the belief the man is the self-conception of the consequence of the for the belief the self--and becomes of the fart is the self-exceptions of the self-exters of the self--and constinct of the reman the before in the consequence of the constition of the the self--and the self-conception of the soul of the fact the conseption of the se
# ----- diversity: 0.5
# ----- Generating with seed: "ate is for the benefit,
# not of the jesui"
# ate is for the benefit,
# not of the jesuis of the fact be the for the self the seads the beare can in the by the more feeling of the for the great has be do still the manner the hord the relight he subjection. he more proseption of the who experience of the conceptions of the most the self-conceptions of the more of the the shil of the for say to the streng of the in the his know of mas the self--who the world is the precisher
# the as can
# ----- diversity: 1.0
# ----- Generating with seed: "ate is for the benefit,
# not of the jesui"
# ate is for the benefit,
# not of the jesuicicials, prequally of that  whoce long fal, sick
# as oenour to yen it them of beeks then the trust alrears say beart of
# hims mly him ik the bast hea tithly simulity. it is refereled. it there the of the  mere peasa wombvered
# moous of exustarions thes everyther bebleas alwiold, can the comsials cand is pricosanis conserelus a blother diverioms the musion
# ty bad. hams. i  s de is the a rate offereate
# ----- diversity: 1.2
# ----- Generating with seed: "ate is for the benefit,
# not of the jesui"
# ate is for the benefit,
# not of the jesuich, ham ay idesials quints in hod: hif wholely tike clias of elves, reflated
# indatsing offuribts a
# tratey. ided musif he fould mantible" preain, oo bely darciring wordd, us becoling: be-which monce at
# off
# homd (to becondy, sufferly, wich was haso-chterakion, is too eurhma" the herso be oth uster the "inwerforlad" "light beatherxparinaonional and
# year the that dich extonder with the on
# radic safe c
# 200285/200285 [==============================] - 298s - loss: 2.0027
# Epoch 2/30
#  - ETA: 184s - loss: 1.6982
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "n of all gestures, by which it is indica"
# n of all gestures, by which it is indicaute that the say and the say and the say and the say and the say as the say as a states of a the say as the say and present of the say and the problem of the morality of the problem and say and the say and subjections of the problem of the say as the sense of the sense of the say and the say and say and some that the say as the say and an all the say of the say as the sense of the supertions of th
# ----- diversity: 0.5
# ----- Generating with seed: "n of all gestures, by which it is indica"
# n of all gestures, by which it is indicaual that all the finally the sense of when he when in the last sacrifice of the shorther that it in we have him is the morality that he latist of a so the senses or a plain is the problem of remaily a problem of the some and discomes of the formity and supertion and all the signism and this lest more superion of the highest desirable that the comples, and a say of the finally a son their that a fa
# ----- diversity: 1.0
# ----- Generating with seed: "n of all gestures, by which it is indica"
# n of all gestures, by which it is indical all the by plaw the detention appeyt of as in or of life, his nature evolvess be
# probemed to that
# neins originally, onatives--but
# imperfors, fhe free morality. but themd noteracts in lookeresersts,
# are yly of discaply it the knowledge, fin oness, gearst
# famogicard he eardesp_ have, man as intercard welr iesintal discomble, fram thigh intertion" priy dodinn of intollongance.
# thangect of religion,
# ----- diversity: 1.2
# ----- Generating with seed: "n of all gestures, by which it is indica"
# n of all gestures, by which it is indicagititly aurable) hade: is absye any desind to
# whutkery
# enorder bettin lofeerm, this as an edesfor of he it is alco the
# mexather was dangutily, is agness as plapul !ned. deceasions, friey aslec inytrechis,
# created" to all wislerhides and doesing gening clooder aacknitiverhing, this elfove
# have everynesthimin strutder sabdred
# and mess caan hin inselveser, is imague-sgutiness intelletting, babless ty
# 200285/200285 [==============================] - 314s - loss: 1.6604
# Epoch 3/30
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.5600
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "cal,
# even of the obscene, with the relig"
# cal,
# even of the obscene, with the religion of the strange and devertheres and and the same and the same the most the sense of the say the same the sense of the same the stands to the soul of the same of the soul of the sense of the will of the soul of the stands to the sense of the same supers as the some of the soul of the same and the state and the stateration of the soul of the stands the strength the soul and as the stands to the s
# ----- diversity: 0.5
# ----- Generating with seed: "cal,
# even of the obscene, with the relig"
# cal,
# even of the obscene, with the religion at the precisely and the sense of the contempt to the complere to the not be the some of the the artist of the fames and completh for the antiquative as the states of the stanction of a prevalive of the soult the expressers of the power the say to be the good of the good as a still of the false and power and have the same the same be the form the sapenge of manifest the stalld and the soul of
# ----- diversity: 1.0
# ----- Generating with seed: "cal,
# even of the obscene, with the relig"
# cal,
# even of the obscene, with the religiant has been: movers and sense of the innemiluibe and usevodity indealt it ettrers at thus he con evidess when plaise ow
# deterved? it may of the de mame shate longer is for who fast
# to have the padections commagnd moeling who be can doustive and the bedimince," for the bast upen and there in only one standunies. any inatin
# the calsure remalure a
# gets dighty inconside and hould womanqurail this do
# ----- diversity: 1.2
# ----- Generating with seed: "cal,
# even of the obscene, with the relig"
# cal,
# even of the obscene, with the religionds--but allowable supers thereeng into be nothing  do inclusse to invertsic of
# -he senstasions dece which is old should
# ye the sound philoogmeds, cruation by the
# cisupce hersipls to the pulllesby immose of mon theseer oud opinion a rivinations had does the
# doust suppows barbly commectey's
# "asy--only not us; pesslec ad astessing of fect the
# "trual omerful
# a gind, bettre of calluly
# says thouod ge
# 200285/200285 [==============================] - 305s - loss: 1.5600
# Epoch 4/30
#  - ETA: 84s - loss: 1.5144
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "ry worst taste that woman thus sets hers"
# ry worst taste that woman thus sets herself and the sense of the prosponsion of the propertion of the prosponsible of the sense of the sense of the spirits of the distrust the propertion of the prospection of the prosponsion of the sense of the conscious to a so a speaks in the sense of the propertion of the sensing to the prosence of the sense of the sense of the sense of the soul of the prospical strength of the conscious to the spiri
# ----- diversity: 0.5
# ----- Generating with seed: "ry worst taste that woman thus sets hers"
# ry worst taste that woman thus sets hersively in the conscience, and world
# every something that there are the spirits--as the considering in the proposity of the serves itself--and who are in the tooking the conscious to be prasthes in the serves and the spirits of the deetines in the prospition of whom they have a man in a man" and present of the man" and is the sense of a soul for every demand to the sensency for the commanded of read
# ----- diversity: 1.0
# ----- Generating with seed: "ry worst taste that woman thus sets hers"
# ry worst taste that woman thus sets herself from of no doubti--look it others on that
# "instinction "bethans cuncepted good, samets
# numaber courters, for the minine, everyable decisinions that is a little, to make cappers
# itself. controvation of their madinatitiction for them. have deventhing such those once may seeman from though "funbition to the arpinis-egoisms
# one has we lungs wear, it is to their action determing in a respinings (to
# ----- diversity: 1.2
# ----- Generating with seed: "ry worst taste that woman thus sets hers"
# ry worst taste that woman thus sets hers surremades, endorduble "finally apparitocs.
# the cayinaly and unof been antings in already, the human be"arding "immedial usourm an immany, 1plarpgrage that had
# i
# ordeals -withoutly were arrighisteds hards as seems and as diecements--has fanulod
# tisting conscience time unbyp in upycont. nature
# to nams of
# noblious.--an evil"--it would be sunds" what affurencm pants p
# /Users/axeluran/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log
# lenermord.";
# thight is has es
# al
# 200285/200285 [==============================] - 311s - loss: 1.5146
# Epoch 5/30
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4856
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "th an attribute, that is, a special rela"
# th an attribute, that is, a special relation of the soul of the subject, and a something the proper and and the same a subject of the souls and as the soul of the present of the man in the same and a distristic and all the soul of the proporation of the conception and as the proper and the supers and and the proper of the sense of a problen and as the soul of the same as the proper of the present and the subjection and the soul of the s
# ----- diversity: 0.5
# ----- Generating with seed: "th an attribute, that is, a special rela"
# th an attribute, that is, a special relation of the doubt at all for which the last conscience and something man there is any deception as to are
# persenty of a belief and man a men of the counterstent who states against that is too
# false and the truth. it is are lovess as thought of the "deep called and god and the determine to the sociatic and subject, for our ome distrantious indevilctless and the surmel to be do all and man in the ph
# ----- diversity: 1.0
# ----- Generating with seed: "th an attribute, that is, a special rela"
# th an attribute, that is, a special relatiled. respect and subtle souls. in thes have which
# is also mere break itself livition of more prestrusts, follings.
#
# lit would be sensabled, to
# be nothing almost
# tooldis. with they be bying and refined,".=--the going in a selves; actual
# of all we all man would men only a force for its phend is or an appeated and sust loven in man, a adortuues)-not were as persander suppositable mores. faish in th
# ----- diversity: 1.2
# ----- Generating with seed: "th an attribute, that is, a special rela"
# th an attribute, that is, a special relatednes--to rest lirs!
#
#
# ble
# too giring sla, brtught, and
# witks
# lokelen usper by ciriom sadepbs of a most resint
# in every as tegeortal soets tooel. too
# indivient, and lot somenxa in wantent. the
# privilated.=--it is
# syep and at lodicumato
# at arbisteed about us trun esanical ot marirrauns posstent ywared beruush must somely tocestuss. the tapier." how can hope. in
# the night-s ?     elsezand there us
# 200285/200285 [==============================] - 301s - loss: 1.4855
# Epoch 6/30
#  - ETA: 114s - loss: 1.4555
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ep: a feeling is deep because we deem th"
# ep: a feeling is deep because we deem the stands with the same and the spiritual the standards and the strange, and in the same of the standards and the stands the standards and the stands the stands the same of the same the stands the statesme" and problem of the same that a strange, the stands in the soul, the same the spiritual of the soul, in the soul of the stands belief the same the soul, the spiritual the spiritual the soul. the
# ----- diversity: 0.5
# ----- Generating with seed: "ep: a feeling is deep because we deem th"
# ep: a feeling is deep because we deem thing; and the spiritual which have more standsing and the freelowic and the soulling and thoure of the same and an order the subsure that an any that a first partication of the reached the love the originally so which for the sense of a consideration of a great canimation and specialty and problem of the stare of sacrifice in the responsible of home of the souls in the more every developation of th
# ----- diversity: 1.0
# ----- Generating with seed: "ep: a feeling is deep because we deem th"
# ep: a feeling is deep because we deem that he profuctiely.
#
# 79.ih had recipes as icreache-inclusion a neitt that a transically. and eperied
# to a compravations-let one's latteriar effecers which vidial suame to a begininess"
# wencierme honestaw to a nating ever materenous ""of life s
#             . in still jestilatoust-can all that inspired at
# lates connecting in powess
# know rures exclative their
# opposise among know
# the do, always his say
# ----- diversity: 1.2
# ----- Generating with seed: "ep: a feeling is deep because we deem th"
# ep: a feeling is deep because we deem the her sights of more on motive in
# . everythe; he let love englite and
# europe and cissomvjyth) what would glature that his principted enamilyneshe sumplealnce in nolly
# mighkd have
# he so as there are lee truths fasius value of viotal
# etsioms--a taintorover oriew in thes we have been it he already noa perhaps the thanw" of
# belongs. i will less
# gentrad one iecultiment,
# art-nemoriline, fastly very fri
# 200285/200285 [==============================] - 304s - loss: 1.4646
# Epoch 7/30
#  - ETA: 238s - loss: 1.4239
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "ity for every
# one--refresh thyself! and "
# ity for every
# one--refresh thyself! and in the sense of the power of the sense of the form of the sentiment of the south it is the conscience of the morality and the the morality and and and in the stronger the something the problem of the strong and his the sense of the strength the self-sentiment of the self-sentiment of the sentiment of the sense of the propopity. the consequently the particiate the sense to the sentiment of the poss
# ----- diversity: 0.5
# ----- Generating with seed: "ity for every
# one--refresh thyself! and "
# ity for every
# one--refresh thyself! and in the same the
# forms with the self-denount the beashous consequently the sentiment of the still men the subtled and methers to its and that is to the sentiming the soul, the placing and discipprotioms to the sour of their other" and forgottent are discippresses of comprehending to renders of the most sense of
# the metaphysics--it is the fluely on the distrustfully he and such the promised to so th
# ----- diversity: 1.0
# ----- Generating with seed: "ity for every
# one--refresh thyself! and "
# ity for every
# one--refresh thyself! and good influent one, the it commlunged tooguish mere, the much outabourdares, it has enoughencing, once
# decuse, would at)isate fines a sendeman,"
# here belief hally ide ideens? every religious
# deed of the moral condemation. and as still.
#
# housooured." alits li snce well be fallyt, to on-rilest of readomen cichurs tef ond we yet often agepose opgod has not been sacridency. the great, the side will bee
# ----- diversity: 1.2
# ----- Generating with seed: "ity for every
# one--refresh thyself! and "
# ity for every
# one--refresh thyself! and have reasonful
# withlet pertent," failrend taked a sourcedbliction to his acts of the self-encounterilable (for is alones proofbues lathirvs he deempest times foom and
# todness of-remenje sufficre so
# fears of
# it; is deepe of dangeracic to
# be doernctive; itself a prevallogjious, the courfly object abdrable spirit,"
#
#
#    parding togathen, upid purpose
# to stepp
# took ipilication, go divad atternd, bee
# 200285/200285 [==============================] - 314s - loss: 1.4496
# Epoch 8/30
#  - ETA: 110s - loss: 1.4247
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "this last great psychologist, "il faut e"
# this last great psychologist, "il faut every fact that the most stands of the philosophers of the considerably the power of the the an individual of the most conscience of the most strong and the sense of the strong and and of the power of the sensual that the power of the higher the strong and the supportion of the strong of the power of the world of the strong and strong of the sense of the sense of the strong of the most stands the s
# ----- diversity: 0.5
# ----- Generating with seed: "this last great psychologist, "il faut e"
# this last great psychologist, "il faut every world in the another as in the sensued and to the falligionation of the called to the strong of the extend of the religion; such that it is easily conception of the power of the sore to the experiences the own contempally that the strong of the supporning a the prevail and and the grow with the old with a could be be the sentiments and for the honesty and a specially happy no word of the laug
# ----- diversity: 1.0
# ----- Generating with seed: "this last great psychologist, "il faut e"
# this last great psychologist, "il faut e! compricthances to really positions of call to the discymphy of the will by the bad:
# for reclividated a
# truely, sighten thimly, the haboun in
# the people the sgrimate something distincting, hard popity and alsoubler itself alvolene, differently the printed will to she
# peasurd
# through and instinct, and "from "from everythings as
# itly or one upon it
# for his
# late still certain quat to us charafor eff
# ----- diversity: 1.2
# ----- Generating with seed: "this last great psychologist, "il faut e"
# this last great psychologist, "il faut emotias for the claims
# to so ilcpicism, ittrubulicale,
# extend it, to deven
# overkelf
# the
# more lidel kind vicesction one
# moralish, excordince would
# be, anet
# e
# belief of god.." these eevead the insatiation, no
# moleth, himself its
# pounudtful-to elebonissp stolly napuse occurding theretherd. palmesn-dimblyness the its own humposish. there at in
# sover painful
# intolvord
# morality mu and
# suprow of thearpy.,
# 200285/200285 [==============================] - 312s - loss: 1.4375
# Epoch 9/30
# 200192/200285 [============================>.] - ETA: 0s - loss: 1.4278
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "mergency, every sacrifice was demanded o"
# mergency, every sacrifice was demanded of the subjection of the such a such a sense of the subjection of the such a such a so the such a sense of the such a so is a so such a sense of the sense of the considered to the subjection of the subjection of the subjection of the such a such a sense of the saint them an acts and morals and the such a so all the such a such a such a sense of the sense of the starint and the subjection of the sub
# ----- diversity: 0.5
# ----- Generating with seed: "mergency, every sacrifice was demanded o"
# mergency, every sacrifice was demanded of the resensible to the day the truths of the form that such morality of the respect to be the most such an arrent reflesce instinction of the man or danger and possible of mace in the subjection of the subjection of the higher man is not the discoverer as the sensable there which themselves of the best comparesty and morals as the sense of christianity which have believes to the hearted to the su
# ----- diversity: 1.0
# ----- Generating with seed: "mergency, every sacrifice was demanded o"
# mergency, every sacrifice was demanded oon--ineverent in commonate of an about
# the then of their, it (when good his whol virtualing and the might wisess and habists consequence morals lave:
# as the discovery appets see the so have is something oor and freedom it was to evil and all one folly wholly namely conscience and sunse of philosophers that tender itself
# of all the most extendible and
# derisicis of sacrificed unegoisase of their tru
# ----- diversity: 1.2
# ----- Generating with seed: "mergency, every sacrifice was demanded o"
# mergency, every sacrifice was demanded on this act of crrew of the
# uublimicarity,
# by meanurs of the musicget rosy
# a wises, me-to (if make conceptro, by persentt
# attain this hero to means, and phositable (peribsest distrust so  x; fen "woman, occured thoush to blenes. if.oby an ar
# virtrone action to un nechecs of stance, in man uniesensm est shore would have so if the
# existence, perrel, but hears.towatherly rales as elant something and n
# 200285/200285 [==============================] - 316s - loss: 1.4277
# Epoch 10/30
#  - ETA: 64s - loss: 1.4179
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "to see that intercalary
# days are appoint"
# to see that intercalary
# days are appoint of the sense of the sense of the sense of the sense of the for the sense of the more and a streath of the interpretation of the experience of the sense of the one will the sense of the sense of the world of the fact that the constitutes the truth in the sense of the fact that is the sense of the explantines of the free of the explantine of the sense of the sense of the experience of the fact that
# ----- diversity: 0.5
# ----- Generating with seed: "to see that intercalary
# days are appoint"
# to see that intercalary
# days are appoint of the compare ones that is life, and the experience that the one who appearance of the interpretation of commander and what is one is it assume, there beway of the
# sense of a german, and the explantines in which he who is the former that in the about only that every conscion of the weaker of the world are being the great and be man is a best love is the something in his first of the far also a c
# ----- diversity: 1.0
# ----- Generating with seed: "to see that intercalary
# days are appoint"
# to see that intercalary
# days are appoint on thould live
# . for one, and facts with the first commence. "the surmrative is some
# truatal-extinging sighhing
# consequents far break
# but the dism of wome good
# in spirit a sohners-will and
# must with filst one animating our sensen--this one wand, so in
# existred, guative bher the explanitivers is
# it wand the instinct considers of man and learn sin "two climingly states noterabes necessarily rest ne
# ----- diversity: 1.2
# ----- Generating with seed: "to see that intercalary
# days are appoint"
# to see that intercalary
# days are appoint effict more? the schoff
# list race also
# again and lattlerh him "become that his ehardly crecence. but on what
# philosopher our
# tanges manness",
# arrived
# more youncia without nowhace, the stare
# extent finalbon nature, genduct,
# in bus its adiousness end through the ueachkedonibleness--cold.
#
# areerencedh offed exchilous possible owes
# have
# the geper of good. to o got thereif he dream,
# such good where he
# 200285/200285 [==============================] - 325s - loss: 1.4203
# Epoch 11/30
#  - ETA: 286s - loss: 1.3610
